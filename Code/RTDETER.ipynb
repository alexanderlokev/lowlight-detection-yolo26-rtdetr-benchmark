# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.3 MB/s eta 0:00:00
# ...
# Mounted at /content/drive
# Copying dataset to Colab local storage...
# Dataset copied successfully.
# data.yaml updated.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import shutil

# Paths
drive_path = "/content/drive/MyDrive/ccpd26dark"
local_path = "/content/ccpd26dark"


# Copy dataset to local storage
if not os.path.exists(local_path):
    print("Copying dataset to Colab local storage...")
    shutil.copytree(drive_path, local_path)
    print("Dataset copied successfully.")
else:
    print("Dataset already exists in local storage.")

# Fix data.yaml paths
data_yaml_path = os.path.join(local_path, "data.yaml")

with open(data_yaml_path, "r") as f:
    data_yaml = f.read()

data_yaml = data_yaml.replace("/content/drive/MyDrive/ccpd26dark", local_path)

with open(data_yaml_path, "w") as f:
    f.write(data_yaml)

print("data.yaml updated.")

# %%
#Train Model
from ultralytics import RTDETR

model = RTDETR("rtdetr-l.pt")

model.train(
    data="/content/ccpdyolo26/data.yaml",

    #Core Settings
    epochs=120,
    imgsz=640,
    batch=8,
    lr0=0.0001,
    workers=2,
    cache=False,

    #Auto Save Drive
    project="/content/drive/MyDrive",
    name="RTDETR_normal",
    save=True
)

# %%
#Resume Model Training
from ultralytics import RTDETR

model = RTDETR(
    "/content/drive/MyDrive/RTDETR_normal/weights/last.pt"
)

model.train(
    resume=True,
    project="/content/drive/MyDrive",
    name="RTDETR_normal"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.33 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
#load best model change according model used RTDETR or YOLO
from ultralytics import RTDETR

model = RTDETR("/content/drive/MyDrive/deeplearning_assignment_1/trained models/RTDETR_normal/weights/best.pt")

# %%
metrics = model.val(
    data="/content/ccpd26dark/data.yaml",
    split="test",
)
# Out:
# Ultralytics 8.4.35 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26m summary (fused): 132 layers, 20,350,223 parameters, 0 gradients, 67.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2099.5±618.7 MB/s, size: 64.2 KB)
# val: Scanning /content/ccpd26dark/ccpd_train_yolo/test/labels.cache... 771 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 771/771 294.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 49/49 3.2it/s 15.3s
#                    all        771        771          1      0.996      0.995      0.957
# Speed: 1.1ms preprocess, 15.8ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /content/runs/detect/val2

# %%
#view Test results
map50 = metrics.box.map50
map5095 = metrics.box.map

print("mAP@0.5:", map50)
print("mAP@0.5:0.95:", map5095)
# Out:
# mAP@0.5: 0.995
# mAP@0.5:0.95: 0.9570759626278977

# %%
#save test result
import pandas as pd
import os

save_dir = "/content/drive/MyDrive/deeplearning_assignment_1/RTDETR_normal"
os.makedirs(save_dir, exist_ok=True)

df = pd.DataFrame([{
    "model": "RTDETR",
    "condition": "normal",
    "mAP@0.5": metrics.box.map50,
    "mAP@0.5:0.95": metrics.box.map
}])

df.to_csv(f"{save_dir}/results.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1533/3822436302.py in <cell line: 0>()
#       8     "model": "YOLOv26m",
#       9     "condition": "normal",
# ---> 10     "mAP@0.5": metrics.box.map50,
#      11     "mAP@0.5:0.95": metrics.box.map
#      12 }])
#
# NameError: name 'metrics' is not defined
